# %% [markdown]
# 1. Contains Duplicate
# python

# %%
def containsDuplicate(nums):
    seen = set()  # Just need to track if seen, not index
    
    for num in nums:
        if num in seen:
            return True
        seen.add(num)
    
    return False

# %% [markdown]
# 2. Valid Anagram (frequency count variation)
# python

# %%
def isAnagram(s, t):
    if len(s) != len(t):
        return False
    
    count = {}
    
    # Count characters in s
    for char in s:
        count[char] = count.get(char, 0) + 1
    
    # Subtract characters in t
    for char in t:
        if char not in count:
            return False
        count[char] -= 1
        if count[char] < 0:
            return False
    
    return True

# %% [markdown]
# 3. Two Sum with different return (variations)
# python# Return the actual numbers, not indices

# %%
def twoSumValues(nums, target):
    seen = set()
    
    for num in nums:
        complement = target - num
        if complement in seen:
            return [complement, num]
        seen.add(num)
    
    return []
