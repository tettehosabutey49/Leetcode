# %% [markdown]
# ## BFS Pattern

# %%
from collections import deque

def bfs_template(start):
    if not start:
        return []  # or appropriate base case
    
    queue = deque([start])
    result = []  # or whatever you're collecting
    
    while queue:
        # Optional: Track level
        for _ in range(len(queue)):  # Process one level
            node = queue.popleft()
            
            # Do something with node
            result.append(node.val)
            
            # Add children/neighbors to queue
            if node.left:
                queue.append(node.left)
            if node.right:
                queue.append(node.right)
    
    return result

# %%
#1. Level Order Traversal (LC 102)
def levelOrder(root):
    if not root:
        return []
    
    result = []
    queue = deque([root])
    
    while queue:
        level = []  # Collect this level
        for _ in range(len(queue)):
            node = queue.popleft()
            level.append(node.val)
            
            if node.left:
                queue.append(node.left)
            if node.right:
                queue.append(node.right)
        
        result.append(level)
    
    return result

# %% [markdown]
# 111. Minimum Depth of Binary Tree
# Easy
# Topics
# premium lock icon
# Companies
# Given a binary tree, find its minimum depth.
#
# The minimum depth is the number of nodes along the shortest path from the root node down to the nearest leaf node.
#
# Note: A leaf is a node with no children.
#
#
#
# Example 1:
#
#
# Input: root = [3,9,20,null,null,15,7]
# Output: 2
# Example 2:
#
# Input: root = [2,null,3,null,4,null,5,null,6]
# Output: 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution(object):
    def minDepth(self, root):
        """
        :type root: Optional[TreeNode]
        :rtype: int
        """
        #Use BFS, meaning we will be using a queue
        #capture edge case
        if not root:
            return 0 

        depth = 1
        queue = deque([(root, depth)])


        while queue:                                #supervisor, check if there more work for "for loop" after each level processing
            for _ in range(len(queue)):             #take snapshot of level and process it
                node, depth = queue.popleft()

                if not node.left and not node.right:        #if there is no deeper level/child return the original depth
                    return depth 

                if node.left:                                #add left child, and increase level
                    queue.append((node.left, depth+1))
                
                if node.right:                                 #add right child and increase level
                    queue.append((node.right, depth+1))
